# %%
# Import thư viện
import pandas as pd
import numpy as np
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score 

# Lấy dữ liệu dạng Dataframe từ file dữ liệu 
DATASET_inflation = pd.read_csv('https://raw.githubusercontent.com/phatjkk/world_inflation_data/main/world_CPI.csv')

# %%
# Lấy số liệu của Việt Nam
VN_inflation = DATASET_inflation.T[257] # Vietnam
# Loại bỏ các năm có số liệu bị rỗng
VN_inflation = VN_inflation[4:].dropna()
print(VN_inflation)
# Out:
# 1995      40.16572
# 1996     42.445125
# 1997     43.807412
# 1998     46.990546
# 1999     48.925195
# 2000     48.088409
# 2001     47.880886
# 2002      49.71512
# 2003      51.32323
# 2004     55.303319
# 2005     59.884963
# 2006     64.327239
# 2007     69.694993
# 2008     85.805303
# 2009     91.568831
# 2010         100.0
# 2011    118.677732
# 2012     129.47112
# 2013     138.00673
# 2014     143.64369
# 2015     144.55037
# 2016    148.407333
# 2017    153.631652
# 2018    159.069641
# 2019    163.516948
# 2020    168.783722
# 2021    171.880423
# Name: 257, dtype: object

# %%
# Vẽ biểu đồ trực quan hoá dữ liệu
import matplotlib.pyplot as plt
plt.plot(VN_inflation)
plt.title('Số liệu CPI Việt Nam')
plt.xlabel("Năm") 
plt.ylabel("Giá trị CPI")
plt.xticks(rotation=60)
plt.show()

# %%
# Chuẩn hoá dữ liệu, scale dữ liệu về khoảng [0, 1]
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
VN_inflation = sc.fit_transform(VN_inflation.to_numpy()
                                .reshape(-1,1).tolist())
VN_inflation = VN_inflation.flatten()

# %%
# Phân lớp dữ liệu ra làm 2 phần X, Y
X,Y=[],[]
range_X = 5
for i in range(range_X,len(VN_inflation)):
    X.append(VN_inflation[i-range_X:i].tolist())
    Y.append(VN_inflation[i])

Y = np.array(Y).reshape(-1,1).tolist()

print(X)
print(Y)
# Out:
# [[0.0, 0.017305620328262217, 0.0276483332221526, 0.05181521272711931, 0.06650338979409387], [0.017305620328262217, 0.0276483332221526, 0.05181521272711931, 0.06650338979409387, 0.060150372057569346], [0.0276483332221526, 0.05181521272711931, 0.06650338979409387, 0.060150372057569346, 0.05857482364615646], [0.05181521272711931, 0.06650338979409387, 0.060150372057569346, 0.05857482364615646, 0.07250063851490013], [0.06650338979409387, 0.060150372057569346, 0.05857482364615646, 0.07250063851490013, 0.08470967221937686], [0.060150372057569346, 0.05857482364615646, 0.07250063851490013, 0.08470967221937686, 0.11492717588370127], [0.05857482364615646, 0.07250063851490013, 0.08470967221937686, 0.11492717588370127, 0.1497117782044728], [0.07250063851490013, 0.08470967221937686, 0.11492717588370127, 0.1497117782044728, 0.18343828497823844], [0.08470967221937686, 0.11492717588370127, 0.1497117782044728, 0.18343828497823844, 0.2241911662090602], [0.11492717588370127, 0.1497117782044728, 0.18343828497823844, 0.2241911662090602, 0.34650332913571746], [0.1497117782044728, 0.18343828497823844, 0.2241911662090602, 0.34650332913571746, 0.39026099079749266], [0.18343828497823844, 0.2241911662090602, 0.34650332913571746, 0.39026099079749266, 0.45427183576388463], [0.2241911662090602, 0.34650332913571746, 0.39026099079749266, 0.45427183576388463, 0.5960762962456202], [0.34650332913571746, 0.39026099079749266, 0.45427183576388463, 0.5960762962456202, 0.6780214968184276], [0.39026099079749266, 0.45427183576388463, 0.5960762962456202, 0.6780214968184276, 0.7428252715653256], [0.45427183576388463, 0.5960762962456202, 0.6780214968184276, 0.7428252715653256, 0.7856220125571172], [0.5960762962456202, 0.6780214968184276, 0.7428252715653256, 0.7856220125571172, 0.7925056806976505], [0.6780214968184276, 0.7428252715653256, 0.7856220125571172, 0.7925056806976505, 0.8217883843902842], [0.7428252715653256, 0.7856220125571172, 0.7925056806976505, 0.8217883843902842, 0.8614522890871761], [0.7856220125571172, 0.7925056806976505, 0.8217883843902842, 0.8614522890871761, 0.902738409043538], [0.7925056806976505, 0.8217883843902842, 0.8614522890871761, 0.902738409043538, 0.9365031036574718], [0.8217883843902842, 0.8614522890871761, 0.902738409043538, 0.9365031036574718, 0.9764893277253395]]
# [[0.060150372057569346], [0.05857482364615646], [0.07250063851490013], [0.08470967221937686], [0.11492717588370127], [0.1497117782044728], [0.18343828497823844], [0.2241911662090602], [0.34650332913571746], [0.39026099079749266], [0.45427183576388463], [0.5960762962456202], [0.6780214968184276], [0.7428252715653256], [0.7856220125571172], [0.7925056806976505], [0.8217883843902842], [0.8614522890871761], [0.902738409043538], [0.9365031036574718], [0.9764893277253395], [1.0]]

# %%
from sklearn.model_selection import train_test_split
# Cắt tập dữ liệu X, Y theo tỷ lệ 80/20 (80% training, 20% test)
x_training, x_test, y_training, y_test = train_test_split(X,Y,test_size=0.20,
                                                          shuffle=True,
                                                          random_state=0)

# %%
from keras.models import Sequential
from keras.layers import LSTM,Dropout,Dense
lstm_model=Sequential()
lstm_model.add(LSTM(units=128,return_sequences=True,
                    activation='relu',
                    input_shape=(range_X,1)))
lstm_model.add(LSTM(units=64))
lstm_model.add(Dropout(0.5))
lstm_model.add(Dense(1))


lstm_model.compile(loss='mean_squared_error',optimizer='adam')
lstm_model.fit(x_training,y_training,epochs=150,batch_size=5,verbose=2)
# Out:
# Epoch 1/150
# 4/4 - 9s - loss: 0.3385 - 9s/epoch - 2s/step
# Epoch 2/150
# 4/4 - 0s - loss: 0.2735 - 41ms/epoch - 10ms/step
# Epoch 3/150
# 4/4 - 0s - loss: 0.2097 - 40ms/epoch - 10ms/step
# Epoch 4/150
# 4/4 - 0s - loss: 0.1398 - 41ms/epoch - 10ms/step
# Epoch 5/150
# 4/4 - 0s - loss: 0.0752 - 41ms/epoch - 10ms/step
# Epoch 6/150
# 4/4 - 0s - loss: 0.0350 - 43ms/epoch - 11ms/step
# Epoch 7/150
# 4/4 - 0s - loss: 0.0563 - 42ms/epoch - 11ms/step
# Epoch 8/150
# 4/4 - 0s - loss: 0.0463 - 41ms/epoch - 10ms/step
# Epoch 9/150
# 4/4 - 0s - loss: 0.0358 - 47ms/epoch - 12ms/step
# Epoch 10/150
# 4/4 - 0s - loss: 0.0277 - 42ms/epoch - 11ms/step
# Epoch 11/150
# 4/4 - 0s - loss: 0.0191 - 43ms/epoch - 11ms/step
# Epoch 12/150
# 4/4 - 0s - loss: 0.0145 - 42ms/epoch - 11ms/step
# Epoch 13/150
# 4/4 - 0s - loss: 0.0220 - 42ms/epoch - 10ms/step
# Epoch 14/150
# 4/4 - 0s - loss: 0.0281 - 47ms/epoch - 12ms/step
# Epoch 15/150
# 4/4 - 0s - loss: 0.0223 - 44ms/epoch - 11ms/step
# Epoch 16/150
# 4/4 - 0s - loss: 0.0232 - 43ms/epoch - 11ms/step
# Epoch 17/150
# 4/4 - 0s - loss: 0.0186 - 43ms/epoch - 11ms/step
# Epoch 18/150
# 4/4 - 0s - loss: 0.0116 - 44ms/epoch - 11ms/step
# Epoch 19/150
# 4/4 - 0s - loss: 0.0170 - 42ms/epoch - 11ms/step
# Epoch 20/150
# 4/4 - 0s - loss: 0.0225 - 53ms/epoch - 13ms/step
# Epoch 21/150
# 4/4 - 0s - loss: 0.0187 - 41ms/epoch - 10ms/step
# Epoch 22/150
# 4/4 - 0s - loss: 0.0102 - 44ms/epoch - 11ms/step
# Epoch 23/150
# 4/4 - 0s - loss: 0.0154 - 43ms/epoch - 11ms/step
# Epoch 24/150
# 4/4 - 0s - loss: 0.0153 - 43ms/epoch - 11ms/step
# Epoch 25/150
# 4/4 - 0s - loss: 0.0238 - 41ms/epoch - 10ms/step
# Epoch 26/150
# 4/4 - 0s - loss: 0.0292 - 45ms/epoch - 11ms/step
# Epoch 27/150
# 4/4 - 0s - loss: 0.0243 - 46ms/epoch - 12ms/step
# Epoch 28/150
# 4/4 - 0s - loss: 0.0175 - 43ms/epoch - 11ms/step
# Epoch 29/150
# 4/4 - 0s - loss: 0.0347 - 48ms/epoch - 12ms/step
# Epoch 30/150
# 4/4 - 0s - loss: 0.0093 - 44ms/epoch - 11ms/step
# Epoch 31/150
# 4/4 - 0s - loss: 0.0162 - 43ms/epoch - 11ms/step
# Epoch 32/150
# 4/4 - 0s - loss: 0.0085 - 42ms/epoch - 11ms/step
# Epoch 33/150
# 4/4 - 0s - loss: 0.0152 - 44ms/epoch - 11ms/step
# Epoch 34/150
# 4/4 - 0s - loss: 0.0097 - 42ms/epoch - 11ms/step
# Epoch 35/150
# 4/4 - 0s - loss: 0.0180 - 43ms/epoch - 11ms/step
# Epoch 36/150
# 4/4 - 0s - loss: 0.0099 - 41ms/epoch - 10ms/step
# Epoch 37/150
# 4/4 - 0s - loss: 0.0131 - 42ms/epoch - 10ms/step
# Epoch 38/150
# 4/4 - 0s - loss: 0.0185 - 52ms/epoch - 13ms/step
# Epoch 39/150
# 4/4 - 0s - loss: 0.0158 - 43ms/epoch - 11ms/step
# Epoch 40/150
# 4/4 - 0s - loss: 0.0247 - 45ms/epoch - 11ms/step
# Epoch 41/150
# 4/4 - 0s - loss: 0.0162 - 43ms/epoch - 11ms/step
# Epoch 42/150
# 4/4 - 0s - loss: 0.0171 - 44ms/epoch - 11ms/step
# Epoch 43/150
# 4/4 - 0s - loss: 0.0064 - 41ms/epoch - 10ms/step
# Epoch 44/150
# 4/4 - 0s - loss: 0.0069 - 43ms/epoch - 11ms/step
# Epoch 45/150
# 4/4 - 0s - loss: 0.0203 - 42ms/epoch - 11ms/step
# Epoch 46/150
# 4/4 - 0s - loss: 0.0083 - 42ms/epoch - 11ms/step
# Epoch 47/150
# 4/4 - 0s - loss: 0.0124 - 43ms/epoch - 11ms/step
# Epoch 48/150
# 4/4 - 0s - loss: 0.0102 - 41ms/epoch - 10ms/step
# Epoch 49/150
# 4/4 - 0s - loss: 0.0083 - 49ms/epoch - 12ms/step
# Epoch 50/150
# 4/4 - 0s - loss: 0.0097 - 45ms/epoch - 11ms/step
# Epoch 51/150
# 4/4 - 0s - loss: 0.0075 - 43ms/epoch - 11ms/step
# Epoch 52/150
# 4/4 - 0s - loss: 0.0094 - 42ms/epoch - 10ms/step
# Epoch 53/150
# 4/4 - 0s - loss: 0.0130 - 41ms/epoch - 10ms/step
# Epoch 54/150
# 4/4 - 0s - loss: 0.0111 - 43ms/epoch - 11ms/step
# Epoch 55/150
# 4/4 - 0s - loss: 0.0120 - 51ms/epoch - 13ms/step
# Epoch 56/150
# 4/4 - 0s - loss: 0.0090 - 42ms/epoch - 11ms/step
# Epoch 57/150
# 4/4 - 0s - loss: 0.0084 - 41ms/epoch - 10ms/step
# Epoch 58/150
# 4/4 - 0s - loss: 0.0070 - 42ms/epoch - 11ms/step
# Epoch 59/150
# 4/4 - 0s - loss: 0.0083 - 47ms/epoch - 12ms/step
# Epoch 60/150
# 4/4 - 0s - loss: 0.0122 - 42ms/epoch - 11ms/step
# Epoch 61/150
# 4/4 - 0s - loss: 0.0061 - 44ms/epoch - 11ms/step
# Epoch 62/150
# 4/4 - 0s - loss: 0.0118 - 43ms/epoch - 11ms/step
# Epoch 63/150
# 4/4 - 0s - loss: 0.0048 - 43ms/epoch - 11ms/step
# Epoch 64/150
# 4/4 - 0s - loss: 0.0117 - 42ms/epoch - 10ms/step
# Epoch 65/150
# 4/4 - 0s - loss: 0.0092 - 44ms/epoch - 11ms/step
# Epoch 66/150
# 4/4 - 0s - loss: 0.0097 - 44ms/epoch - 11ms/step
# Epoch 67/150
# 4/4 - 0s - loss: 0.0176 - 43ms/epoch - 11ms/step
# Epoch 68/150
# 4/4 - 0s - loss: 0.0107 - 48ms/epoch - 12ms/step
# Epoch 69/150
# 4/4 - 0s - loss: 0.0153 - 47ms/epoch - 12ms/step
# Epoch 70/150
# 4/4 - 0s - loss: 0.0105 - 45ms/epoch - 11ms/step
# Epoch 71/150
# 4/4 - 0s - loss: 0.0034 - 42ms/epoch - 10ms/step
# Epoch 72/150
# 4/4 - 0s - loss: 0.0080 - 43ms/epoch - 11ms/step
# Epoch 73/150
# 4/4 - 0s - loss: 0.0110 - 43ms/epoch - 11ms/step
# Epoch 74/150
# 4/4 - 0s - loss: 0.0089 - 41ms/epoch - 10ms/step
# Epoch 75/150
# 4/4 - 0s - loss: 0.0077 - 61ms/epoch - 15ms/step
# Epoch 76/150
# 4/4 - 0s - loss: 0.0113 - 68ms/epoch - 17ms/step
# Epoch 77/150
# 4/4 - 0s - loss: 0.0057 - 69ms/epoch - 17ms/step
# Epoch 78/150
# 4/4 - 0s - loss: 0.0085 - 65ms/epoch - 16ms/step
# Epoch 79/150
# 4/4 - 0s - loss: 0.0100 - 67ms/epoch - 17ms/step
# Epoch 80/150
# 4/4 - 0s - loss: 0.0117 - 63ms/epoch - 16ms/step
# Epoch 81/150
# 4/4 - 0s - loss: 0.0142 - 59ms/epoch - 15ms/step
# Epoch 82/150
# 4/4 - 0s - loss: 0.0057 - 60ms/epoch - 15ms/step
# Epoch 83/150
# 4/4 - 0s - loss: 0.0099 - 63ms/epoch - 16ms/step
# Epoch 84/150
# 4/4 - 0s - loss: 0.0076 - 65ms/epoch - 16ms/step
# Epoch 85/150
# 4/4 - 0s - loss: 0.0046 - 69ms/epoch - 17ms/step
# Epoch 86/150
# 4/4 - 0s - loss: 0.0038 - 64ms/epoch - 16ms/step
# Epoch 87/150
# 4/4 - 0s - loss: 0.0081 - 61ms/epoch - 15ms/step
# Epoch 88/150
# 4/4 - 0s - loss: 0.0128 - 62ms/epoch - 15ms/step
# Epoch 89/150
# 4/4 - 0s - loss: 0.0096 - 62ms/epoch - 15ms/step
# Epoch 90/150
# 4/4 - 0s - loss: 0.0026 - 63ms/epoch - 16ms/step
# Epoch 91/150
# 4/4 - 0s - loss: 0.0068 - 65ms/epoch - 16ms/step
# Epoch 92/150
# 4/4 - 0s - loss: 0.0039 - 73ms/epoch - 18ms/step
# Epoch 93/150
# 4/4 - 0s - loss: 0.0024 - 61ms/epoch - 15ms/step
# Epoch 94/150
# 4/4 - 0s - loss: 0.0043 - 61ms/epoch - 15ms/step
# Epoch 95/150
# 4/4 - 0s - loss: 0.0130 - 41ms/epoch - 10ms/step
# Epoch 96/150
# 4/4 - 0s - loss: 0.0064 - 44ms/epoch - 11ms/step
# Epoch 97/150
# 4/4 - 0s - loss: 0.0047 - 42ms/epoch - 11ms/step
# Epoch 98/150
# 4/4 - 0s - loss: 0.0113 - 42ms/epoch - 11ms/step
# Epoch 99/150
# 4/4 - 0s - loss: 0.0113 - 43ms/epoch - 11ms/step
# Epoch 100/150
# 4/4 - 0s - loss: 0.0061 - 45ms/epoch - 11ms/step
# Epoch 101/150
# 4/4 - 0s - loss: 0.0069 - 44ms/epoch - 11ms/step
# Epoch 102/150
# 4/4 - 0s - loss: 0.0071 - 50ms/epoch - 12ms/step
# Epoch 103/150
# 4/4 - 0s - loss: 0.0014 - 58ms/epoch - 14ms/step
# Epoch 104/150
# 4/4 - 0s - loss: 0.0076 - 43ms/epoch - 11ms/step
# Epoch 105/150
# 4/4 - 0s - loss: 0.0091 - 44ms/epoch - 11ms/step
# Epoch 106/150
# 4/4 - 0s - loss: 0.0051 - 45ms/epoch - 11ms/step
# Epoch 107/150
# 4/4 - 0s - loss: 0.0130 - 43ms/epoch - 11ms/step
# Epoch 108/150
# 4/4 - 0s - loss: 0.0034 - 45ms/epoch - 11ms/step
# Epoch 109/150
# 4/4 - 0s - loss: 0.0026 - 43ms/epoch - 11ms/step
# Epoch 110/150
# 4/4 - 0s - loss: 0.0033 - 42ms/epoch - 11ms/step
# Epoch 111/150
# 4/4 - 0s - loss: 0.0043 - 47ms/epoch - 12ms/step
# Epoch 112/150
# 4/4 - 0s - loss: 9.6683e-04 - 43ms/epoch - 11ms/step
# Epoch 113/150
# 4/4 - 0s - loss: 0.0076 - 46ms/epoch - 12ms/step
# Epoch 114/150
# 4/4 - 0s - loss: 0.0036 - 42ms/epoch - 11ms/step
# Epoch 115/150
# 4/4 - 0s - loss: 0.0110 - 41ms/epoch - 10ms/step
# Epoch 116/150
# 4/4 - 0s - loss: 0.0048 - 41ms/epoch - 10ms/step
# Epoch 117/150
# 4/4 - 0s - loss: 0.0038 - 40ms/epoch - 10ms/step
# Epoch 118/150
# 4/4 - 0s - loss: 0.0032 - 43ms/epoch - 11ms/step
# Epoch 119/150
# 4/4 - 0s - loss: 0.0082 - 42ms/epoch - 10ms/step
# Epoch 120/150
# 4/4 - 0s - loss: 0.0068 - 42ms/epoch - 11ms/step
# Epoch 121/150
# 4/4 - 0s - loss: 0.0092 - 43ms/epoch - 11ms/step
# Epoch 122/150
# 4/4 - 0s - loss: 0.0073 - 45ms/epoch - 11ms/step
# Epoch 123/150
# 4/4 - 0s - loss: 0.0057 - 46ms/epoch - 11ms/step
# Epoch 124/150
# 4/4 - 0s - loss: 0.0048 - 44ms/epoch - 11ms/step
# Epoch 125/150
# 4/4 - 0s - loss: 0.0099 - 42ms/epoch - 10ms/step
# Epoch 126/150
# 4/4 - 0s - loss: 0.0077 - 49ms/epoch - 12ms/step
# Epoch 127/150
# 4/4 - 0s - loss: 0.0046 - 41ms/epoch - 10ms/step
# Epoch 128/150
# 4/4 - 0s - loss: 0.0116 - 40ms/epoch - 10ms/step
# Epoch 129/150
# 4/4 - 0s - loss: 0.0023 - 42ms/epoch - 10ms/step
# Epoch 130/150
# 4/4 - 0s - loss: 0.0114 - 49ms/epoch - 12ms/step
# Epoch 131/150
# 4/4 - 0s - loss: 0.0078 - 43ms/epoch - 11ms/step
# Epoch 132/150
# 4/4 - 0s - loss: 0.0091 - 44ms/epoch - 11ms/step
# Epoch 133/150
# 4/4 - 0s - loss: 0.0044 - 42ms/epoch - 11ms/step
# Epoch 134/150
# 4/4 - 0s - loss: 0.0039 - 45ms/epoch - 11ms/step
# Epoch 135/150
# 4/4 - 0s - loss: 0.0083 - 41ms/epoch - 10ms/step
# Epoch 136/150
# 4/4 - 0s - loss: 0.0052 - 42ms/epoch - 11ms/step
# Epoch 137/150
# 4/4 - 0s - loss: 0.0135 - 43ms/epoch - 11ms/step
# Epoch 138/150
# 4/4 - 0s - loss: 0.0061 - 45ms/epoch - 11ms/step
# Epoch 139/150
# 4/4 - 0s - loss: 0.0057 - 41ms/epoch - 10ms/step
# Epoch 140/150
# 4/4 - 0s - loss: 0.0031 - 45ms/epoch - 11ms/step
# Epoch 141/150
# 4/4 - 0s - loss: 0.0088 - 41ms/epoch - 10ms/step
# Epoch 142/150
# 4/4 - 0s - loss: 0.0046 - 43ms/epoch - 11ms/step
# Epoch 143/150
# 4/4 - 0s - loss: 0.0057 - 41ms/epoch - 10ms/step
# Epoch 144/150
# 4/4 - 0s - loss: 0.0037 - 42ms/epoch - 11ms/step
# Epoch 145/150
# 4/4 - 0s - loss: 0.0036 - 43ms/epoch - 11ms/step
# Epoch 146/150
# 4/4 - 0s - loss: 0.0079 - 42ms/epoch - 11ms/step
# Epoch 147/150
# 4/4 - 0s - loss: 0.0036 - 44ms/epoch - 11ms/step
# Epoch 148/150
# 4/4 - 0s - loss: 0.0078 - 43ms/epoch - 11ms/step
# Epoch 149/150
# 4/4 - 0s - loss: 0.0061 - 44ms/epoch - 11ms/step
# Epoch 150/150
# 4/4 - 0s - loss: 0.0042 - 42ms/epoch - 11ms/step

# %%
pred_y_test = lstm_model.predict(x_test)

x_ax=range(len(x_test))
plt.plot(x_ax, y_test, lw=1.5, color="red",
         label="Kết quả thực tế")
plt.plot(x_ax, pred_y_test, lw=1.5, color="blue",
         label="Kết quả dự đoán")
plt.title("Kết quả dự đoán trên tập Test")
plt.legend()
plt.show()

# Hiển thị sai số.
pred_y_test = pred_y_test.tolist()

mse = mean_squared_error(y_test, pred_y_test)
print("Mean Squared Error:",mse)
rmse = math.sqrt(mse)
print("Root Mean Squared Error:", rmse)
print("R2 Score: ",r2_score(y_test, pred_y_test))
# Out:
# 1/1 [==============================] - 1s 633ms/step
# Mean Squared Error: 0.0012084337146885007
# Root Mean Squared Error: 0.03476253320298307
# R2 Score:  0.9881737928643447

# %% [markdown]
# # Dự đoán CPI năm tiếp theo (2022)

# %%
# Lấy dữ liệu 5 năm gần nhất trong tập (2017 -> 2021)
nearest_5_year = np.array([VN_inflation[-5:]])
nearest_5_year
# Out:
# array([[0.86145229, 0.90273841, 0.9365031 , 0.97648933, 1.        ]])

# %%
# Đưa dữ liệu vào mô hình dự đoán
pred_2022 = lstm_model.predict(nearest_5_year)
# Out:
# 1/1 [==============================] - 0s 35ms/step

# %%
# Kết quả dự đoán (CHƯA unscale giá trị) 
pred_2022
# Out:
# array([[1.0160544]], dtype=float32)

# %%
# Kết quả dự đoán CPI NĂM 2022 (ĐÃ unscale) 
sc.inverse_transform(pred_2022)
# Số CPI thực tế của VN 2022 là: 177.31
# Out:
# array([[173.99503]], dtype=float32)
